# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('roadac2012_AnnexureXI.csv')

# %%
df
# Out:
#                  States/UTs  \
# 0            Andhra Pradesh
# 1         Arunachal Pradesh
# 2                     Assam
# 3                     Bihar
# 4              Chhattisgarh
# 5                       Goa
# 6                   Gujarat
# 7                   Haryana
# 8          Himachal Pradesh
# 9         Jammu and Kashmir
# 10                Jharkhand
# 11                Karnataka
# 12                   Kerala
# 13           Madhya Pradesh
# 14              Maharashtra
# 15                  Manipur
# 16                Meghalaya
# 17                  Mizoram
# 18                 Nagaland
# 19                   Odisha
# 20                   Punjab
# 21                Rajasthan
# 22                   Sikkim
# 23               Tamil Nadu
# 24                  Tripura
# 25              Uttarakhand
# 26            Uttar Pradesh
# 27              West Bengal
# 28  Andaman and Nicobar Is.
# 29               Chandigarh
# 30   Dadra and Nagar Haveli
# 31            Daman and Diu
# ...

# %%
df["States/UTs"].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Tripura', 'Uttarakhand', 'Uttar Pradesh', 'West Bengal',
#        'Andaman and Nicobar Is.', 'Chandigarh', 'Dadra and Nagar Haveli',
#        'Daman and Diu', 'Delhi **', 'Lakshadweep', 'Puducherry'], dtype=object)

# %%
df["States/UTs"].nunique()
# Out:
# 35

# %%
df['Total No. of Road Accidents due to Fault of Driver']
# Out:
# 0     33222
# 1        79
# 2      6184
# 3      6225
# 4      9178
# 5      3954
# 6     23980
# 7      7890
# 8      2662
# 9      4350
# 10     3374
# 11    36545
# 12    36142
# 13    40975
# 14    56418
# 15        0
# 16       23
# 17      110
# 18        5
# 19     8781
# 20     3804
# 21    21939
# 22       11
# 23    57507
# 24      705
# 25     1013
# 26    12759
# 27     6191
# 28      236
# 29      419
# 30       85
# 31       40
# 32        0
# 33        3
# 34     1125
# Name: Total No. of Road Accidents due to Fault of Driver, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size':18})
y=df['Total No. of Road Accidents due to Fault of Driver']
yd=df['States/UTs'].iloc[:35].unique()
p=df['States/UTs'].nunique()
d=np.linspace(1,p,p)
plt.bar(d,y,align='center')
plt.xticks(d,yd,rotation=90)
plt.xlabel('States')
plt.ylabel('No. of accidents')
plt.title('Total no. of Accidents')
plt.show()

# %%
df[df['Total No. of Road Accidents due to Fault of Driver']<40000]['States/UTs'].nunique()
# Out:
# 32

# %%
df['States/UTs'].iloc[:35].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Tripura', 'Uttarakhand', 'Uttar Pradesh', 'West Bengal',
#        'Andaman and Nicobar Is.', 'Chandigarh', 'Dadra and Nagar Haveli',
#        'Daman and Diu', 'Delhi **', 'Lakshadweep', 'Puducherry'], dtype=object)

# %%
df2=pd.read_csv('Total_No_of_Road_Accidents_in_States_UTs_2003-15.csv')
df2
# Out:
#                      States/UTs      2003      2004      2005      2006  \
# 0                Andhra Pradesh   34826.0   38940.0   37131.0   43559.0
# 1             Arunachal Pradesh     245.0     241.0     231.0     250.0
# 2                         Assam    3262.0    3688.0    4258.0    4694.0
# 3                         Bihar    6141.0    4027.0    3768.0    5594.0
# 4                  Chhattisgarh   10521.0   10600.0   11164.0   11934.0
# 5                           Goa    3244.0    3525.0    3577.0    3707.0
# 6                       Gujarat   30604.0   30630.0   30515.0   31547.0
# 7                       Haryana    8690.0    9321.0    9298.0   10314.0
# 8              Himachal Pradesh    2680.0    2808.0    2797.0    2727.0
# 9               Jammu & Kashmir    5904.0    6257.0    5664.0    5593.0
# 10                    Jharkhand    4211.0    4614.0    5013.0    4980.0
# 11                    Karnataka   37658.0   38869.0   40330.0   43411.0
# ...

# %%
df2.columns
# Out:
# Index(['States/UTs', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
df2['States/UTs']
# Out:
# 0                  Andhra Pradesh
# 1               Arunachal Pradesh
# 2                           Assam
# 3                           Bihar
# 4                    Chhattisgarh
# 5                             Goa
# 6                         Gujarat
# 7                         Haryana
# 8                Himachal Pradesh
# 9                 Jammu & Kashmir
# 10                      Jharkhand
# 11                      Karnataka
# 12                         Kerala
# 13                 Madhya Pradesh
# 14                    Maharashtra
# 15                        Manipur
# 16                      Meghalaya
# 17                        Mizoram
# 18                       Nagaland
# 19                         Odisha
# 20                         Punjab
# 21                      Rajasthan
# 22                         Sikkim
# 23                     Tamil Nadu
# 24                      Telangana
# 25                        Tripura
# 26                    Uttarakhand
# ...

# %%
df3=pd.DataFrame(columns=['Year', 'Count'])

# %%
df3['Year']=df2[df2['States/UTs']=='All India'].columns[1:]

# %%
df3=df2[df2["States/UTs"]=="All India"]
df4=df3.T
df4
# Out:
#                    36
# States/UTs  All India
# 2003           406726
# 2004           429910
# 2005           439255
# 2006           460920
# 2007           479216
# 2008           484704
# 2009           486384
# 2010           499628
# 2011           497686
# 2012           490383
# 2013           486476
# 2014           489400
# 2015           501423

# %%
df4.iloc[1:].plot(figsize=(12,6),legend=False)
plt.xlabel("Year")
plt.ylabel("No. of Accidents")
plt.title("No. of Accidents/ Year")

# %%
df4.head()
# Out:
#                    36
# States/UTs  All India
# 2003           406726
# 2004           429910
# 2005           439255
# 2006           460920

# %%
df.head()
# Out:
#           States/UTs  Total No. of Road Accidents due to Fault of Driver  \
# 0     Andhra Pradesh                                              33222
# 1  Arunachal Pradesh                                                 79
# 2              Assam                                               6184
# 3              Bihar                                               6225
# 4       Chhattisgarh                                               9178
#
#    Number of Persons Killed due to Fault of Driver  \
# 0                                            11492
# 1                                               46
# 2                                             2134
# 3                                             3082
# 4                                             1991
#
#    Number of Persons Injured due to Fault of Driver  \
# 0                                             32982
# 1                                                81
# 2                                              6469
# ...

# %%
print(df2["2012"].ix[36])#Total no. of Road Accidents in 2012
# Out:
# 490383.0
# C:\Users\Debadri\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
#2012
print("Total no. of Road Accidents: ",df2["2012"].ix[36])
print("Total No. of Road Accidents due to Fault of Driver: ",df["Total No. of Road Accidents due to Fault of Driver"].sum())
print("Total No. of Road Accidents due to Defect in Road Condition: ",df["Total No. of Road Accidents due to Defect in Road Condition"].sum())
a=df["Total No. of Road Accidents due to Fault of Driver"].sum()







c=df["Total No. of Road Accidents due to Defect in Road Condition"].sum()
print("Total no. of accidents that can be prevented: ",(a+c))
p=(a+c)/(df2["2012"].ix[36])*100
print("Percentage of accidents that can be  prevented: ",p,"%")
# Out:
# Total no. of Road Accidents:  490383.0
# Total No. of Road Accidents due to Fault of Driver:  385934
# Total No. of Road Accidents due to Defect in Road Condition:  6796
# Total no. of accidents that can be prevented:  392730
# Percentage of accidents that can be  prevented:  80.086381461 %

# %%
x=df["Total No. of Road Accidents due to Defect in Road Condition"].sum()
y=df["Number of Persons Killed due to Defect in Road Condition"].sum()
z=df["Number of Persons Injured due to Defect in Road Condition"].sum()
print(x)
print(y)
print(z)
# Out:
# 6796
# 2346
# 7432

# %%
x1=df2["2012"].ix[:35].sum()
x1
# Out:
# 490383.0

# %%
d=[{"Total no. of Road Accidents":x1,
  "No. of Accidents due to Road Conditions":x,
  "Number of Persons Killed due to Defect in Road Condition":y,
  "Number of Persons Injured due to Defect in Road Condition":z}]
df5=pd.DataFrame(d)
df5
# Out:
#    No. of Accidents due to Road Conditions  \
# 0                                     6796
#
#    Number of Persons Injured due to Defect in Road Condition  \
# 0                                               7432
#
#    Number of Persons Killed due to Defect in Road Condition  \
# 0                                               2346
#
#    Total no. of Road Accidents
# 0                     490383.0

# %%
a=df5["Total no. of Road Accidents"]-df5["No. of Accidents due to Road Conditions"]
print(a)
df5["Total no. of Road Accidents"]
# Out:
# 0    483587.0
# dtype: float64
# 0    490383.0
# Name: Total no. of Road Accidents, dtype: float64

# %%
d1=[{"Total no. of Road Accidents":x1,
     "Accidents with better road conditions":a}]
df6=pd.DataFrame(d1) 
df6
# Out:
#   Accidents with better road conditions  Total no. of Road Accidents
# 0          0    483587.0
# dtype: float64                     490383.0

# %%
sns.pairplot(df5,font_size=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-ccbac36e566c> in <module>()
# ----> 1 sns.pairplot(df5,font_size=1)
#
# TypeError: pairplot() got an unexpected keyword argument 'font_size'
